# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.model_selection import train_test_split

import xgboost as xgb
# !pip install catboost
from catboost import CatBoostClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.3.0)

# %%
df = pd.read_csv('data_music.csv')
print(df)
df = df.drop(df.index[-1])
df = df[df['gatunek_muzyczny'] != 'CLASSICAL']
df = df[df['gatunek_muzyczny'] != 'RAP']
# Out:
#                   tytuły       0.0  14.700000000000417  29.400000000000837  \
# 0     CLASSICAL (10).csv  0.018598            0.019710            0.026129
# 1     CLASSICAL (11).csv  0.020094            0.021792            0.030528
# 2     CLASSICAL (12).csv  0.023951            0.027250            0.042674
# 3     CLASSICAL (13).csv  0.017387            0.019881            0.031651
# 4     CLASSICAL (14).csv  0.024191            0.025585            0.031639
# ...                  ...       ...                 ...                 ...
# 4661        RAP (96).csv  0.064476            0.072189            0.088634
# 4662        RAP (97).csv  0.070935            0.072482            0.090877
# 4663        RAP (98).csv  0.055050            0.059856            0.069300
# 4664        RAP (99).csv  0.050170            0.053780            0.062213
# 4665             RAP.csv  0.102308            0.069869            0.085094
#
#       44.09999999999917  58.80000000000167      73.5  88.19999999999834  \
# 0              0.034257           0.033491  0.034253           0.046652
# 1              0.039912           0.039356  0.040032           0.049217
# 2              0.056833           0.056438  0.060785           0.074739
# 3              0.038155           0.045568  0.036252           0.039478
# 4              0.047100           0.061467  0.059400           0.079311
# ...                 ...                ...       ...                ...
# 4661           0.131892           0.313801  0.378662           0.439307
# 4662           0.138501           0.375301  0.569359           0.196486
# 4663           0.086604           0.136017  0.392125           0.445495
# 4664           0.083484           0.124091  0.311917           0.397640
# 4665           0.124833           0.279902  0.548853           0.310302
#
#       102.89999999999704  117.60000000000332  ...  21932.399999999387  \
# 0               0.085335            0.111911  ...            0.000546
# 1               0.064983            0.094156  ...            0.000751
# 2               0.102983            0.155505  ...            0.000562
# 3               0.037464            0.041645  ...            0.001096
# 4               0.130765            0.156053  ...            0.000555
# ...                  ...                 ...  ...                 ...
# 4661            0.215397            0.223459  ...            0.000581
# 4662            0.199006            0.172736  ...            0.001063
# 4663            0.472284            0.314360  ...            0.000648
# 4664            0.438547            0.204029  ...            0.000726
# 4665            0.217334            0.148097  ...            0.000538
#
#       21947.100000000613  21961.800000000523   21976.5  21991.19999999948  \
# 0               0.000546            0.000546  0.000546           0.000546
# 1               0.000753            0.000750  0.000739           0.000721
# 2               0.000562            0.000562  0.000562           0.000562
# 3               0.001098            0.001100  0.001101           0.001103
# 4               0.000555            0.000554  0.000554           0.000554
# ...                  ...                 ...       ...                ...
# 4661            0.000581            0.000581  0.000581           0.000581
# 4662            0.001063            0.001062  0.001062           0.001062
# 4663            0.000647            0.000647  0.000647           0.000646
# 4664            0.000725            0.000725  0.000725           0.000724
# 4665            0.000538            0.000538  0.000538           0.000538
#
#       22005.899999999387  22020.600000000617  22035.30000000051   22050.0  \
# 0               0.000546            0.000546           0.000546  0.000546
# 1               0.000698            0.000671           0.000647  0.000635
# 2               0.000562            0.000562           0.000562  0.000562
# 3               0.001104            0.001104           0.001105  0.001105
# 4               0.000553            0.000553           0.000553  0.000553
# ...                  ...                 ...                ...       ...
# 4661            0.000581            0.000581           0.000581  0.000581
# 4662            0.001061            0.001061           0.001061  0.001061
# 4663            0.000646            0.000646           0.000646  0.000646
# 4664            0.000724            0.000724           0.000724  0.000724
# 4665            0.000538            0.000538           0.000538  0.000538
#
#       gatunek_muzyczny
# 0            CLASSICAL
# 1            CLASSICAL
# 2            CLASSICAL
# 3            CLASSICAL
# 4            CLASSICAL
# ...                ...
# 4661               RAP
# 4662               RAP
# 4663               RAP
# 4664               RAP
# 4665               RAP
#
# [4666 rows x 1503 columns]

# %%
# git
# df.describe()
# print(df.columns)
df_y = df.iloc[:, -1]

print(df_y)

df_x = df.iloc[:, :-1]

df_x = df_x.drop(df_x.columns[0], axis=1)

# print(df_x.head(20))
# Out:
# 572     COUNTRY
# 573     COUNTRY
# 574     COUNTRY
# 575     COUNTRY
# 576     COUNTRY
#          ...
# 4284        POP
# 4285        POP
# 4286        POP
# 4287        POP
# 4288        POP
# Name: gatunek_muzyczny, Length: 3717, dtype: object

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(df_y)
print(y_encoded.max())
print(y_encoded)
df_y4 = y_encoded[y_encoded == 4]
print(len(df_y4))

print(df_y[df_y == "HIPHOP"])
print(df_y[df_y == "COUNTRY"])
print(df_y[df_y == "JAZZ"])
print(df_y[df_y == "POP"])

# hiphop - 2389
# country - 572
# Out:
# 3
# [0 0 0 ... 3 3 3]
# 0
# 1555    HIPHOP
# 1556    HIPHOP
# 1557    HIPHOP
# 1558    HIPHOP
# 1559    HIPHOP
#          ...
# 2385    HIPHOP
# 2386    HIPHOP
# 2387    HIPHOP
# 2388    HIPHOP
# 2389    HIPHOP
# Name: gatunek_muzyczny, Length: 835, dtype: object
# 572     COUNTRY
# 573     COUNTRY
# 574     COUNTRY
# 575     COUNTRY
# 576     COUNTRY
#          ...
# 1550    COUNTRY
# 1551    COUNTRY
# 1552    COUNTRY
# 1553    COUNTRY
# 1554    COUNTRY
# Name: gatunek_muzyczny, Length: 983, dtype: object
# 2390    JAZZ
# 2391    JAZZ
# 2392    JAZZ
# 2393    JAZZ
# 2394    JAZZ
#         ...
# 3425    JAZZ
# 3426    JAZZ
# 3427    JAZZ
# 3428    JAZZ
# 3429    JAZZ
# Name: gatunek_muzyczny, Length: 1040, dtype: object
# 3430    POP
# 3431    POP
# 3432    POP
# 3433    POP
# 3434    POP
#        ...
# 4284    POP
# 4285    POP
# 4286    POP
# 4287    POP
# 4288    POP
# Name: gatunek_muzyczny, Length: 859, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(df_x, y_encoded, test_size=0.15, random_state=42)

# %%
# regresja logitowa
model = LogisticRegression()
model.fit(X_train, y_train)

y_val_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_val_pred)

print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.6720430107526881
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# drzewo decyzyjne
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

y_val_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_val_pred)

print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.5716845878136201

# %%
# drzewo losowe
model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.6935483870967742

# %%
# działa za długo >30 min
# gradient boost
model = GradientBoostingClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy: {accuracy}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-fb345e5181d0> in <cell line: 3>()
#       1 # gradient boost
#       2 model = GradientBoostingClassifier()
# ----> 3 model.fit(X_train, y_train)
#       4
#       5 y_pred = model.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py in fit(self, X, y, sample_weight, monitor)
#     536
#     537         # fit the boosting stages
# --> 538         n_stages = self._fit_stages(
#     539             X,
#     540             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     613
#     614             # fit next stage of trees
# --> 615             raw_predictions = self._fit_stage(
#     616                 i,
#     617                 X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     255
#     256             X = X_csr if X_csr is not None else X
# --> 257             tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     258
#     259             # update tree leaves
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1245         """
#    1246
# -> 1247         super().fit(
#    1248             X,
#    1249             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     377             )
#     378
# --> 379         builder.build(self.tree_, X, y, sample_weight)
#     380
#     381         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
# k neighbors
model = KNeighborsClassifier()
model.fit(X_train, y_train)


model.fit(X_train, y_train, eval_metric=["logloss", "error"], eval_set=eval_set, verbose=True)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.6505376344086021

# %%
# model = CatBoostClassifier()
# model.fit(X_train, y_train, eval_set=(X_val, y_val), verbose=False)

# y_val_pred = model.predict(X_val)

# accuracy = accuracy_score(y_val, y_val_pred)
# print("Accuracy:", accuracy)

# %%
# model = xgb.XGBClassifier()
# eval_set = [(X_train, y_train), (X_test, y_test)]
# model.fit(X_train, y_train)

# y_val_pred = model.predict(X_test)

# accuracy = accuracy_score(y_test, y_val_pred)
# print("Accuracy:", accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-18-f8565fc923c5> in <cell line: 4>()
#       2 eval_set = [(X_train, y_train), (X_test, y_test)]
#       3 # model.fit(X_train, y_train)
# ----> 4 model.fit(X_train, y_train, eval_metric=["logloss", "error"], eval_set=eval_set, verbose=True)
#       5
#       6 y_val_pred = model.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     728             for k, arg in zip(sig.parameters, args):
#     729                 kwargs[k] = arg
# --> 730             return func(**kwargs)
#     731
#     732         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1517             )
#    1518
# -> 1519             self._Booster = train(
#    1520                 params,
#    1521                 train_dmatrix,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     728             for k, arg in zip(sig.parameters, args):
#     729                 kwargs[k] = arg
# --> 730             return func(**kwargs)
#     731
#     732         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     180             break
#     181         bst.update(dtrain, i, obj)
# --> 182         if cb_container.after_iteration(bst, i, dtrain, evals):
#     183             break
#     184
#
# /usr/local/lib/python3.10/dist-packages/xgboost/callback.py in after_iteration(self, model, epoch, dtrain, evals)
#     236             for _, name in evals:
#     237                 assert name.find("-") == -1, "Dataset name should not contain `-`"
# --> 238             score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#     239             metric_score = _parse_eval_str(score)
#     240             self._update_history(metric_score, epoch)
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in eval_set(self, evals, iteration, feval, output_margin)
#    2123         evnames = c_array(ctypes.c_char_p, [c_str(d[1]) for d in evals])
#    2124         msg = ctypes.c_char_p()
# -> 2125         _check_call(
#    2126             _LIB.XGBoosterEvalOneIter(
#    2127                 self.handle,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in _check_call(ret)
#     280     """
#     281     if ret != 0:
# --> 282         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     283
#     284
#
# XGBoostError: [12:57:13] /workspace/src/metric/elementwise_metric.cu:346: Check failed: preds.Size() == info.labels.Size() (12636 vs. 3159) : label and prediction size not match, hint: use merror or mlogloss for multi-class classification
# Stack trace:
#   [bt] (0) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x927f4a) [0x7d96fd5b5f4a]
#   [bt] (1) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x995e40) [0x7d96fd623e40]
#   [bt] (2) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x4efea5) [0x7d96fd17dea5]
#   [bt] (3) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x4f0168) [0x7d96fd17e168]
#   [bt] (4) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x4c8ab0) [0x7d96fd156ab0]
#   [bt] (5) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(XGBoosterEvalOneIter+0x2f6) [0x7d96fcdf8bb6]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x7d9765d83e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x7d9765d80493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa3e9) [0x7d9765da93e9]

# %%
model = xgb.XGBClassifier(eval_metric=["mlogloss", "merror"])

# Trenowanie modelu z monitorowaniem zestawów treningowego i testowego
eval_set = [(X_train, y_train), (X_test, y_test)]
model.fit(X_train, y_train, eval_set=eval_set, verbose=True)

# Przewidywanie na zbiorze testowym
y_test_pred = model.predict(X_test)

# Ocena modelu (np. accuracy)
accuracy = accuracy_score(y_test, y_test_pred)
print("Accuracy:", accuracy)

# Uzyskanie wyników ewaluacji
results = model.evals_result()

# Wyświetlanie krzywej uczenia się
epochs = len(results['validation_0']['mlogloss'])
x_axis = range(0, epochs)
# Out:
# [0]	validation_0-mlogloss:1.13988	validation_0-merror:0.24913	validation_1-mlogloss:1.21540	validation_1-merror:0.39964
# [1]	validation_0-mlogloss:0.97886	validation_0-merror:0.20450	validation_1-mlogloss:1.10668	validation_1-merror:0.37634
# [2]	validation_0-mlogloss:0.85862	validation_0-merror:0.18740	validation_1-mlogloss:1.03442	validation_1-merror:0.37634
# [3]	validation_0-mlogloss:0.76047	validation_0-merror:0.16936	validation_1-mlogloss:0.98273	validation_1-merror:0.36380
# [4]	validation_0-mlogloss:0.68252	validation_0-merror:0.15543	validation_1-mlogloss:0.93836	validation_1-merror:0.34050
# [5]	validation_0-mlogloss:0.61294	validation_0-merror:0.14308	validation_1-mlogloss:0.90633	validation_1-merror:0.34409
# [6]	validation_0-mlogloss:0.56164	validation_0-merror:0.13454	validation_1-mlogloss:0.88354	validation_1-merror:0.32258
# [7]	validation_0-mlogloss:0.52181	validation_0-merror:0.12979	validation_1-mlogloss:0.85766	validation_1-merror:0.33154
# [8]	validation_0-mlogloss:0.48084	validation_0-merror:0.12187	validation_1-mlogloss:0.84514	validation_1-merror:0.33333
# [9]	validation_0-mlogloss:0.44721	validation_0-merror:0.11649	validation_1-mlogloss:0.83114	validation_1-merror:0.32079
# [10]	validation_0-mlogloss:0.41804	validation_0-merror:0.11143	validation_1-mlogloss:0.82465	validation_1-merror:0.31720
# [11]	validation_0-mlogloss:0.39403	validation_0-merror:0.10890	validation_1-mlogloss:0.81545	validation_1-merror:0.32975
# [12]	validation_0-mlogloss:0.37130	validation_0-merror:0.10636	validation_1-mlogloss:0.80954	validation_1-merror:0.31720
# [13]	validation_0-mlogloss:0.35464	validation_0-merror:0.10510	validation_1-mlogloss:0.80246	validation_1-merror:0.32437
# [14]	validation_0-mlogloss:0.33672	validation_0-merror:0.10383	validation_1-mlogloss:0.80098	validation_1-merror:0.31720
# [15]	validation_0-mlogloss:0.31956	validation_0-merror:0.10193	validation_1-mlogloss:0.79952	validation_1-merror:0.32258
# [16]	validation_0-mlogloss:0.30719	validation_0-merror:0.10003	validation_1-mlogloss:0.79587	validation_1-merror:0.32616
# [17]	validation_0-mlogloss:0.29616	validation_0-merror:0.09940	validation_1-mlogloss:0.79379	validation_1-merror:0.31720
# [18]	validation_0-mlogloss:0.28602	validation_0-merror:0.09908	validation_1-mlogloss:0.78968	validation_1-merror:0.31183
# [19]	validation_0-mlogloss:0.27814	validation_0-merror:0.09845	validation_1-mlogloss:0.78779	validation_1-merror:0.30824
# [20]	validation_0-mlogloss:0.26900	validation_0-merror:0.09782	validation_1-mlogloss:0.78989	validation_1-merror:0.30824
# [21]	validation_0-mlogloss:0.26160	validation_0-merror:0.09687	validation_1-mlogloss:0.79137	validation_1-merror:0.31183
# [22]	validation_0-mlogloss:0.25326	validation_0-merror:0.09687	validation_1-mlogloss:0.79457	validation_1-merror:0.30287
# [23]	validation_0-mlogloss:0.24684	validation_0-merror:0.09687	validation_1-mlogloss:0.79799	validation_1-merror:0.30287
# [24]	validation_0-mlogloss:0.23994	validation_0-merror:0.09687	validation_1-mlogloss:0.80091	validation_1-merror:0.30287
# [25]	validation_0-mlogloss:0.23359	validation_0-merror:0.09687	validation_1-mlogloss:0.80536	validation_1-merror:0.29928
# [26]	validation_0-mlogloss:0.22750	validation_0-merror:0.09687	validation_1-mlogloss:0.81140	validation_1-merror:0.29749
# [27]	validation_0-mlogloss:0.22363	validation_0-merror:0.09687	validation_1-mlogloss:0.81317	validation_1-merror:0.30108
# [28]	validation_0-mlogloss:0.21954	validation_0-merror:0.09687	validation_1-mlogloss:0.81509	validation_1-merror:0.29928
# [29]	validation_0-mlogloss:0.21523	validation_0-merror:0.09687	validation_1-mlogloss:0.82162	validation_1-merror:0.29928
# [30]	validation_0-mlogloss:0.21146	validation_0-merror:0.09687	validation_1-mlogloss:0.82490	validation_1-merror:0.29928
# [31]	validation_0-mlogloss:0.20831	validation_0-merror:0.09687	validation_1-mlogloss:0.82839	validation_1-merror:0.29928
# [32]	validation_0-mlogloss:0.20470	validation_0-merror:0.09687	validation_1-mlogloss:0.83142	validation_1-merror:0.30287
# [33]	validation_0-mlogloss:0.20157	validation_0-merror:0.09687	validation_1-mlogloss:0.83933	validation_1-merror:0.29570
# [34]	validation_0-mlogloss:0.19861	validation_0-merror:0.09687	validation_1-mlogloss:0.84508	validation_1-merror:0.28853
# [35]	validation_0-mlogloss:0.19554	validation_0-merror:0.09687	validation_1-mlogloss:0.84931	validation_1-merror:0.29570
# [36]	validation_0-mlogloss:0.19311	validation_0-merror:0.09687	validation_1-mlogloss:0.85512	validation_1-merror:0.29928
# [37]	validation_0-mlogloss:0.19100	validation_0-merror:0.09687	validation_1-mlogloss:0.86050	validation_1-merror:0.29749
# [38]	validation_0-mlogloss:0.18846	validation_0-merror:0.09687	validation_1-mlogloss:0.86657	validation_1-merror:0.30108
# [39]	validation_0-mlogloss:0.18722	validation_0-merror:0.09687	validation_1-mlogloss:0.87010	validation_1-merror:0.30466
# [40]	validation_0-mlogloss:0.18529	validation_0-merror:0.09687	validation_1-mlogloss:0.87561	validation_1-merror:0.30466
# [41]	validation_0-mlogloss:0.18319	validation_0-merror:0.09687	validation_1-mlogloss:0.88291	validation_1-merror:0.30645
# [42]	validation_0-mlogloss:0.18125	validation_0-merror:0.09687	validation_1-mlogloss:0.88897	validation_1-merror:0.30287
# [43]	validation_0-mlogloss:0.17980	validation_0-merror:0.09687	validation_1-mlogloss:0.89238	validation_1-merror:0.30287
# [44]	validation_0-mlogloss:0.17830	validation_0-merror:0.09687	validation_1-mlogloss:0.89525	validation_1-merror:0.30108
# [45]	validation_0-mlogloss:0.17716	validation_0-merror:0.09687	validation_1-mlogloss:0.90074	validation_1-merror:0.29749
# [46]	validation_0-mlogloss:0.17574	validation_0-merror:0.09687	validation_1-mlogloss:0.90551	validation_1-merror:0.30287
# [47]	validation_0-mlogloss:0.17474	validation_0-merror:0.09687	validation_1-mlogloss:0.90986	validation_1-merror:0.30645
# [48]	validation_0-mlogloss:0.17398	validation_0-merror:0.09687	validation_1-mlogloss:0.91139	validation_1-merror:0.30287
# [49]	validation_0-mlogloss:0.17299	validation_0-merror:0.09687	validation_1-mlogloss:0.91589	validation_1-merror:0.30108
# [50]	validation_0-mlogloss:0.17196	validation_0-merror:0.09687	validation_1-mlogloss:0.92337	validation_1-merror:0.30287
# [51]	validation_0-mlogloss:0.17119	validation_0-merror:0.09687	validation_1-mlogloss:0.92775	validation_1-merror:0.30108
# [52]	validation_0-mlogloss:0.17030	validation_0-merror:0.09687	validation_1-mlogloss:0.93107	validation_1-merror:0.30108
# [53]	validation_0-mlogloss:0.16932	validation_0-merror:0.09687	validation_1-mlogloss:0.93844	validation_1-merror:0.30108
# [54]	validation_0-mlogloss:0.16867	validation_0-merror:0.09687	validation_1-mlogloss:0.94225	validation_1-merror:0.30287
# [55]	validation_0-mlogloss:0.16783	validation_0-merror:0.09687	validation_1-mlogloss:0.94642	validation_1-merror:0.30466
# [56]	validation_0-mlogloss:0.16718	validation_0-merror:0.09687	validation_1-mlogloss:0.95113	validation_1-merror:0.30645
# [57]	validation_0-mlogloss:0.16666	validation_0-merror:0.09687	validation_1-mlogloss:0.95295	validation_1-merror:0.30645
# [58]	validation_0-mlogloss:0.16615	validation_0-merror:0.09687	validation_1-mlogloss:0.95573	validation_1-merror:0.30645
# [59]	validation_0-mlogloss:0.16569	validation_0-merror:0.09687	validation_1-mlogloss:0.95722	validation_1-merror:0.30287
# [60]	validation_0-mlogloss:0.16508	validation_0-merror:0.09687	validation_1-mlogloss:0.96134	validation_1-merror:0.30287
# [61]	validation_0-mlogloss:0.16453	validation_0-merror:0.09687	validation_1-mlogloss:0.96768	validation_1-merror:0.30287
# [62]	validation_0-mlogloss:0.16410	validation_0-merror:0.09687	validation_1-mlogloss:0.97222	validation_1-merror:0.30466
# [63]	validation_0-mlogloss:0.16346	validation_0-merror:0.09687	validation_1-mlogloss:0.97716	validation_1-merror:0.31362
# [64]	validation_0-mlogloss:0.16297	validation_0-merror:0.09687	validation_1-mlogloss:0.98137	validation_1-merror:0.31183
# [65]	validation_0-mlogloss:0.16253	validation_0-merror:0.09687	validation_1-mlogloss:0.98448	validation_1-merror:0.30824
# [66]	validation_0-mlogloss:0.16222	validation_0-merror:0.09687	validation_1-mlogloss:0.98744	validation_1-merror:0.30824
# [67]	validation_0-mlogloss:0.16184	validation_0-merror:0.09687	validation_1-mlogloss:0.99033	validation_1-merror:0.30645
# [68]	validation_0-mlogloss:0.16151	validation_0-merror:0.09687	validation_1-mlogloss:0.99280	validation_1-merror:0.30824
# [69]	validation_0-mlogloss:0.16110	validation_0-merror:0.09687	validation_1-mlogloss:0.99639	validation_1-merror:0.30466
# [70]	validation_0-mlogloss:0.16075	validation_0-merror:0.09687	validation_1-mlogloss:0.99804	validation_1-merror:0.30108
# [71]	validation_0-mlogloss:0.16046	validation_0-merror:0.09687	validation_1-mlogloss:1.00181	validation_1-merror:0.30287
# [72]	validation_0-mlogloss:0.16009	validation_0-merror:0.09687	validation_1-mlogloss:1.00562	validation_1-merror:0.30645
# [73]	validation_0-mlogloss:0.15981	validation_0-merror:0.09687	validation_1-mlogloss:1.00810	validation_1-merror:0.30466
# [74]	validation_0-mlogloss:0.15950	validation_0-merror:0.09687	validation_1-mlogloss:1.01057	validation_1-merror:0.30287
# [75]	validation_0-mlogloss:0.15927	validation_0-merror:0.09687	validation_1-mlogloss:1.01252	validation_1-merror:0.30287
# [76]	validation_0-mlogloss:0.15905	validation_0-merror:0.09687	validation_1-mlogloss:1.01546	validation_1-merror:0.30108
# [77]	validation_0-mlogloss:0.15883	validation_0-merror:0.09687	validation_1-mlogloss:1.01687	validation_1-merror:0.30108
# [78]	validation_0-mlogloss:0.15864	validation_0-merror:0.09687	validation_1-mlogloss:1.01869	validation_1-merror:0.30108
# [79]	validation_0-mlogloss:0.15838	validation_0-merror:0.09687	validation_1-mlogloss:1.02250	validation_1-merror:0.30108
# [80]	validation_0-mlogloss:0.15820	validation_0-merror:0.09687	validation_1-mlogloss:1.02364	validation_1-merror:0.29928
# [81]	validation_0-mlogloss:0.15796	validation_0-merror:0.09687	validation_1-mlogloss:1.02697	validation_1-merror:0.29928
# [82]	validation_0-mlogloss:0.15771	validation_0-merror:0.09687	validation_1-mlogloss:1.02934	validation_1-merror:0.30108
# [83]	validation_0-mlogloss:0.15747	validation_0-merror:0.09687	validation_1-mlogloss:1.03285	validation_1-merror:0.29928
# [84]	validation_0-mlogloss:0.15727	validation_0-merror:0.09687	validation_1-mlogloss:1.03650	validation_1-merror:0.30287
# [85]	validation_0-mlogloss:0.15707	validation_0-merror:0.09687	validation_1-mlogloss:1.03766	validation_1-merror:0.30466
# [86]	validation_0-mlogloss:0.15694	validation_0-merror:0.09687	validation_1-mlogloss:1.03841	validation_1-merror:0.29928
# [87]	validation_0-mlogloss:0.15680	validation_0-merror:0.09687	validation_1-mlogloss:1.04116	validation_1-merror:0.29928
# [88]	validation_0-mlogloss:0.15665	validation_0-merror:0.09687	validation_1-mlogloss:1.04502	validation_1-merror:0.30108
# [89]	validation_0-mlogloss:0.15650	validation_0-merror:0.09687	validation_1-mlogloss:1.04807	validation_1-merror:0.30108
# [90]	validation_0-mlogloss:0.15635	validation_0-merror:0.09687	validation_1-mlogloss:1.05081	validation_1-merror:0.30108
# [91]	validation_0-mlogloss:0.15620	validation_0-merror:0.09687	validation_1-mlogloss:1.05129	validation_1-merror:0.30287
# [92]	validation_0-mlogloss:0.15605	validation_0-merror:0.09687	validation_1-mlogloss:1.05145	validation_1-merror:0.30108
# [93]	validation_0-mlogloss:0.15590	validation_0-merror:0.09687	validation_1-mlogloss:1.05470	validation_1-merror:0.29928
# [94]	validation_0-mlogloss:0.15578	validation_0-merror:0.09687	validation_1-mlogloss:1.05612	validation_1-merror:0.30108
# [95]	validation_0-mlogloss:0.15561	validation_0-merror:0.09687	validation_1-mlogloss:1.05908	validation_1-merror:0.30108
# [96]	validation_0-mlogloss:0.15546	validation_0-merror:0.09687	validation_1-mlogloss:1.06116	validation_1-merror:0.30108
# [97]	validation_0-mlogloss:0.15533	validation_0-merror:0.09687	validation_1-mlogloss:1.06369	validation_1-merror:0.29928
# [98]	validation_0-mlogloss:0.15519	validation_0-merror:0.09687	validation_1-mlogloss:1.06630	validation_1-merror:0.30108
# [99]	validation_0-mlogloss:0.15504	validation_0-merror:0.09687	validation_1-mlogloss:1.06965	validation_1-merror:0.29928
# Accuracy: 0.7007168458781362

# %%
# Log loss
plt.figure(figsize=(24, 16))
plt.subplot(2, 2, 1)
plt.plot(x_axis, results['validation_0']['mlogloss'], label='Train')
plt.plot(x_axis, results['validation_1']['mlogloss'], label='Test')
plt.legend()
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
# Out:
# Text(0.5, 1.0, 'XGBoost Log Loss')

# %%
# Classification error
plt.figure(figsize=(24, 16))
plt.subplot(2, 2, 2)
plt.plot(x_axis, results['validation_0']['merror'], label='Train')
plt.plot(x_axis, results['validation_1']['merror'], label='Test')
plt.legend()
plt.ylabel('Classification Error')
plt.title('XGBoost Classification Error')
# Out:
# Text(0.5, 1.0, 'XGBoost Classification Error')

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(24, 24))
plt.subplot(2, 2, 3)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
# ROC Curve
y_test_binarized = label_binarize(y_test, classes=range(len(label_encoder.classes_)))
y_test_pred_proba = model.predict_proba(X_test)
n_classes = y_test_binarized.shape[1]
plt.figure(figsize=(24, 16))
plt.subplot(2, 2, 4)
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_test_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'Class {label_encoder.classes_[i]} (area = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

plt.tight_layout()
plt.show()

# %%
# Wyświetlanie raportu klasyfikacji
print(classification_report(y_test, y_test_pred, target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#      COUNTRY       0.95      0.88      0.91       160
#       HIPHOP       0.83      0.82      0.83       133
#         JAZZ       0.62      0.61      0.62       151
#          POP       0.38      0.43      0.40       114
#
#     accuracy                           0.70       558
#    macro avg       0.69      0.68      0.69       558
# weighted avg       0.71      0.70      0.71       558

# %%
# 1 - country 2 - hip hop 3 - jazz 4 - pop
# y_original_test = label_encoder.inverse_transform(y_test)
# y_original_pred = label_encoder.inverse_transform(y_val_pred)

# cm = confusion_matrix(y_original_test, y_original_pred)

# # Wizualizacja macierzy pomyłek
# plt.figure(figsize=(10, 8))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.title('Confusion Matrix')
# plt.show()

# %%
## dalsze wykresy dla xgboost
# Out:
# 3
